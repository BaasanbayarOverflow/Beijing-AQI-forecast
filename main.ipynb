# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import missingno as msno
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20560\1447995668.py in <module>
#       4 import seaborn as sns
#       5 import plotly.graph_objects as go
# ----> 6 import missingno as msno
#
# ModuleNotFoundError: No module named 'missingno'

# %%
dataframe_aotizhoungxin = pd.read_csv("data/PRSA_Data_Aotizhongxin_20130301-20170228.csv")

# %%
print(f'Dataframe columns: {list(dataframe_aotizhoungxin.columns)}')
dataframe = dataframe_aotizhoungxin.drop(columns=['PRES', 'DEWP', 'RAIN', 'wd', 'WSPM'])
dataframe.head(20)

# %%
msno.matrix(dataframe_aotizhoungxin)
dataframe_aotizhoungxin.isnull().sum()

# %%
dataframe[dataframe['PM10'] == None]
# Out:
# Empty DataFrame
# Columns: [No, year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, TEMP, station]
# Index: []

# %%
dataframe_mean_by_day = dataframe.groupby(['year', 'month', 'day']).mean()

# %%
dataframe.head(30)
# Out:
#     No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0    1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1    2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2    3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3    4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4    5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
# 5    6  2013      3    1     5    5.0   5.0  18.0  18.0  400.0  66.0  -2.2
# 6    7  2013      3    1     6    3.0   3.0  18.0  32.0  500.0  50.0  -2.6
# 7    8  2013      3    1     7    3.0   6.0  19.0  41.0  500.0  43.0  -1.6
# 8    9  2013      3    1     8    3.0   6.0  16.0  43.0  500.0  45.0   0.1
# 9   10  2013      3    1     9    3.0   8.0  12.0  28.0  400.0  59.0   1.2
# 10  11  2013      3    1    10    3.0   6.0   9.0  12.0  400.0  72.0   1.9
# ...

# %%
#for i in range(len(tot_dataframe)): 
#    tot_dataframe[i]['date'] = tot_dataframe[i]['year'].map(str) + '-' + tot_dataframe[i]['month'].map(str) + '-' + tot_dataframe[i]['day'].map(str) + ' ' + tot_dataframe[i]['hour'].map(str) + ':00:00'
#    tot_dataframe[i]['date'] = pd.to_datetime(tot_dataframe[i]['date'])
#    tot_dataframe[i] = tot_dataframe[i].drop(columns=['No', 'year', 'month', 'day', 'hour', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM'])
#    tot_dataframe[i] = tot_dataframe[i].rename(columns={'PM2.5': 'PM2_5'})
#    tot_dataframe[i] = tot_dataframe[i].dropna(axis=0, how='any')

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x = list(tot_dataframe[0]['date']), y = list(tot_dataframe[0]['O3'])))
fig.update_layout(title_text = "Ozon level in the air")
fig.update_layout(
    xaxis = dict(
        rangeselector = dict(
            buttons = list([
                dict(count = 1,
                     label = 'month',
                     step = 'month',
                     stepmode = 'backward'),
                dict(count = 6,
                     label = '6 month',
                     step = 'month',
                     stepmode = 'backward'),
                dict(count = 1,
                     label = 'year',
                     step = 'year',
                     stepmode = 'backward'),
                dict(step = 'all')
            ])
        ),
        rangeslider = dict(
            visible = True,
        ),
        type = 'date',
    )
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8080/21305526.py in <module>
#       1 fig = go.Figure()
# ----> 2 fig.add_trace(go.Scatter(x = list(tot_dataframe[0]['date']), y = list(tot_dataframe[0]['O3'])))
#       3 fig.update_layout(title_text = "Ozon level in the air")
#       4 fig.update_layout(
#       5     xaxis = dict(
#
# NameError: name 'tot_dataframe' is not defined
